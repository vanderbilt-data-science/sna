# %% [markdown]
# # Read in data

# %%
import pandas as pd

# %%
product = pd.read_csv("data/product_catalogue-v0.2.csv")
product.shape
# Out:
# (883868, 7)

# %%
product
# Out:
#         product_id                                      product_title  \
# 0       B0188A3QRM  Amazon Basics Woodcased #2 Pencils, Unsharpene...
# 1       B075VXJ9VG  BAZIC Pencil #2 HB Pencils, Latex Free Eraser,...
# 2       B07G7F6JZ6  Emraw Pre Sharpened Round Primary Size No 2 Ju...
# 3       B07JZJLHCF  Emraw Pre Sharpened Triangular Primary Size No...
# 4       B07MGKC3DD  BIC Evolution Cased Pencil, #2 Lead, Gray Barr...
# ...            ...                                                ...
# 883863  B094NN6T8V    アイリスプラザ コーナーソファ 3点セット 高反発 2人掛け 3人掛け ブラウン 394310
# 883864  B096RD95K9  Uping テーブル・ベッドの高さ調節が簡単にできる ベッドの高さをあげる足 4個セット 高...
# 883865  B099Z4HXH1  アイリスプラザ ソファ ソファー ローソファ ローソファー 1人掛け 1人用 幅約108cm...
# 883866  B09B9QMMSF  足入れヒーター 足温器 電気足温器 1～6時間タイマー 丸洗い可能 省エネ あったか脚入れヒ...
# 883867  B09CNNHRQ1  Mensu ノートパソコンデスク 竹製 折りたたみ式  勉強机 ローテーブル 書見台 ブック...
#
#                                       product_description  \
# 0                                                     NaN
# ...

# %%
train = pd.read_csv("data/train-v0.2.csv")
train.shape
# Out:
# (781738, 5)

# %%
train
# Out:
#         query_id                         query query_locale  product_id  \
# 0              0  !awnmower tires without rims           us  B00004RA3F
# 1              0  !awnmower tires without rims           us  B0018TWDOI
# 2              0  !awnmower tires without rims           us  B005O5Y3QI
# 3              0  !awnmower tires without rims           us  B0089RA0HY
# 4              0  !awnmower tires without rims           us  B0089RNSNM
# ...          ...                           ...          ...         ...
# 781733     33776                         ﾒｽﾃｨﾝ           jp  B0828CGPRH
# 781734     33776                         ﾒｽﾃｨﾝ           jp  B084MF6MKN
# 781735     33776                         ﾒｽﾃｨﾝ           jp  B088D57W66
# 781736     33776                         ﾒｽﾃｨﾝ           jp  B088FR58NN
# 781737     33776                         ﾒｽﾃｨﾝ           jp  B088QJ34Q1
#
#         esci_label
# 0       irrelevant
# 1            exact
# 2            exact
# 3       substitute
# ...

# %%
test = pd.read_csv("data/test_public-v0.2.csv")
test.shape
# Out:
# (167799, 4)

# %%
test
# Out:
#         query_id                         query query_locale  product_id
# 0          33777  !qscreen fence without holes           us  B000HMCA7W
# 1          33777  !qscreen fence without holes           us  B0019Y6TTC
# 2          33777  !qscreen fence without holes           us  B001OJXVKW
# 3          33777  !qscreen fence without holes           us  B0030E1WLE
# 4          33777  !qscreen fence without holes           us  B003VNKLIY
# ...          ...                           ...          ...         ...
# 167794     41021                          ｖｉｖｙ           jp  B097Y3HWT3
# 167795     41021                          ｖｉｖｙ           jp  B098NSGTFC
# 167796     41021                          ｖｉｖｙ           jp  B099DDZJYJ
# 167797     41021                          ｖｉｖｙ           jp  B09BDYND7N
# 167798     41021                          ｖｉｖｙ           jp  B09BRV4HTB
#
# [167799 rows x 4 columns]

# %%
sample = pd.read_csv("data/sample_submission-v0.2.csv")
sample
# Out:
#        product_id  query_id
# 0      B07VCHYQXY     33777
# 1      B07QTCR7NB     33777
# 2      B06Y3JY5HY     33777
# 3      B01LZ1RCMW     33777
# 4      B00VKLPY54     33777
# ...           ...       ...
# 94095  B092Z5FT26     41021
# 94096  B00V5664PS     41021
# 94097  B01DVW6CAU     41021
# 94098  B07B1SCVMV     41021
# 94099  B01MS894C1     41021
#
# [94100 rows x 2 columns]

# %%
train[train['query_id'] == 0]
# Out:
#     query_id                         query query_locale  product_id  \
# 0          0  !awnmower tires without rims           us  B00004RA3F
# 1          0  !awnmower tires without rims           us  B0018TWDOI
# 2          0  !awnmower tires without rims           us  B005O5Y3QI
# 3          0  !awnmower tires without rims           us  B0089RA0HY
# 4          0  !awnmower tires without rims           us  B0089RNSNM
# 5          0  !awnmower tires without rims           us  B00N16T5D8
# 6          0  !awnmower tires without rims           us  B01DBGLLUC
# 7          0  !awnmower tires without rims           us  B01H3KC5U2
# 8          0  !awnmower tires without rims           us  B01M3SJ699
# 9          0  !awnmower tires without rims           us  B06XX6BM2R
# 10         0  !awnmower tires without rims           us  B075SCHMPY
# 11         0  !awnmower tires without rims           us  B077QMNXTS
# 12         0  !awnmower tires without rims           us  B07C1WZG12
# ...
